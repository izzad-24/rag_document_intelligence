# %% [markdown]
# ### General

# %% [markdown]
# #### Pipeline A: Run once
#
# ```mermaid
# graph LR
#     A[Documents
#     PDF or .txt] --> B[Text Splitter
#     Create chunks]
#     B --> C[Embedder]
#     C --> D[Chroma DB
#     Store on disk]
# ```

# %% [markdown]
# #### Pipeline B: Run everytime user ask question
#
# ```mermaid
# graph LR
#     A[Question
#     Type in chat] --> B[Embedder
#     To vector form]
#     B --> C[Vector Search
#     Top-k chunks]
#     C --> D[LLM Groq
#     Response]
# ```

# %% [markdown]
# #### Vector Storage & Retrieval
#
# ```mermaid
# graph LR
#     A[Question
#     Type in chat] --> B[Embedder
#     To vector form]
#     B --> C[Vector Search
#     Top-k chunks]
#     C --> D[LLM Groq
#     Response]
# ```

# %% [markdown]
# #### RAG Chain (Wiring retrieval to LLM)
#
# ```mermaid
# graph LR
#     A[Question
#     Type in chat] --> B[Embedder
#     To vector form]
#     B --> C[Vector Search
#     Top-k chunks]
#     C --> D[LLM Groq
#     Response]
# ```
